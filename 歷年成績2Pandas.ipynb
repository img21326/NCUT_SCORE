# %%
import pandas
df = pandas.read_html('data/參考/歷年成績-碩二.html')
df = df[0]

# %%
df
# Out:
#        學年   學期                            科目名稱  修別    學分    成績    排名   備註
# 0     NaN  NaN  至目前總修習學分(為 及格學分數 +抵免學分),總平均及排名  必修  22.0  63.5  排名:3  NaN
# 1   108.0  上學期                       萃思創意思考與應用  選修   3.0  17.0   NaN    X
# 2   108.0  上學期                          巨量資料分析  選修   3.0   NaN   NaN   抵免
# 3   108.0  上學期                          企業資源規劃  選修   3.0   0.0   NaN    X
# 4   108.0  上學期                              操行  必修   0.0  86.0   NaN  NaN
# 5   108.0  上學期           學期實得學分(及格分數加上抵免學分)及排名  必修  10.0   8.5  排名:4  NaN
# 6   108.0  上學期                         書報討論（一）  必修   1.0   NaN   NaN   抵免
# 7   108.0  上學期                            創新研究  必修   3.0   NaN   NaN   抵免
# 8   108.0  上學期                            研究方法  必修   3.0   NaN   NaN   抵免
# 9   108.0  下學期                            科技管理  選修   3.0  89.0   NaN  NaN
# 10  108.0  下學期                              操行  必修   0.0  85.0   NaN  NaN
# 11  108.0  下學期           學期實得學分(及格分數加上抵免學分)及排名  必修   3.0  89.0  排名:4  NaN
# ...

# %%
df = df[df.排名.isnull()]
df
# Out:
#        學年   學期       科目名稱  修別   學分    成績   排名   備註
# 1   108.0  上學期  萃思創意思考與應用  選修  3.0  17.0  NaN    X
# 2   108.0  上學期     巨量資料分析  選修  3.0   NaN  NaN   抵免
# 3   108.0  上學期     企業資源規劃  選修  3.0   0.0  NaN    X
# 4   108.0  上學期         操行  必修  0.0  86.0  NaN  NaN
# 6   108.0  上學期    書報討論（一）  必修  1.0   NaN  NaN   抵免
# 7   108.0  上學期       創新研究  必修  3.0   NaN  NaN   抵免
# 8   108.0  上學期       研究方法  必修  3.0   NaN  NaN   抵免
# 9   108.0  下學期       科技管理  選修  3.0  89.0  NaN  NaN
# 10  108.0  下學期         操行  必修  0.0  85.0  NaN  NaN
# 12  109.0  上學期  萃思創意思考與應用  選修  3.0  94.0  NaN  NaN
# 13  109.0  上學期         操行  必修  0.0  89.0  NaN  NaN
# 15  109.0  下學期        演算法  選修  3.0  92.0  NaN  NaN
# 16  109.0  下學期         操行  必修  0.0  86.0  NaN  NaN
# 18  109.0  下學期     管理資訊系統  必修  3.0  89.0  NaN  NaN

# %%
df['pass'] = False
df
# Out:
# <ipython-input-4-a1e014ea3fad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pass'] = False
#        學年   學期       科目名稱  修別   學分    成績   排名   備註   pass
# 1   108.0  上學期  萃思創意思考與應用  選修  3.0  17.0  NaN    X  False
# 2   108.0  上學期     巨量資料分析  選修  3.0   NaN  NaN   抵免  False
# 3   108.0  上學期     企業資源規劃  選修  3.0   0.0  NaN    X  False
# 4   108.0  上學期         操行  必修  0.0  86.0  NaN  NaN  False
# 6   108.0  上學期    書報討論（一）  必修  1.0   NaN  NaN   抵免  False
# 7   108.0  上學期       創新研究  必修  3.0   NaN  NaN   抵免  False
# 8   108.0  上學期       研究方法  必修  3.0   NaN  NaN   抵免  False
# 9   108.0  下學期       科技管理  選修  3.0  89.0  NaN  NaN  False
# 10  108.0  下學期         操行  必修  0.0  85.0  NaN  NaN  False
# ...

# %%
df['pass'][df.成績>59] = True
df['pass'][df.備註 == '抵免'] = True
df
# Out:
# <ipython-input-5-4cd6c84b7111>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pass'][df.成績>59] = True
# C:\Users\Liao\Anaconda3\lib\site-packages\pandas\core\series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-5-4cd6c84b7111>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pass'][df.備註 == '抵免'] = True
# ...

# %%
df.to_csv('data/Outputs/歷年成績.csv',encoding='utf-8-sig')
